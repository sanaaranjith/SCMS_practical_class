# %%
# Load the CSV file to inspect its contents and pick out the top 5 countries based on growth percentage
import pandas as pd 
file_path_csv = 'C:/Users/Sana/Downloads/SCMS_practical_class/Python/EDA/data/france_commodities.csv'

# Read the CSV file
df_filtered = pd.read_csv(file_path_csv)

print(df_filtered)
# Out:
#     S.No.  HSCode                                          Commodity  \
# 0       1       3  FISH AND CRUSTACEANS, MOLLUSCS AND OTHER AQUAT...
# 1       2       4  DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDI...
# 2       3       5  PRODUCTS OF ANIMAL ORIGIN, NOT ELSEWHERE SPECI...
# 3       4       6  LIVE TREES AND OTHER PLANTS; BULBS; ROOTS AND ...
# 4       5       7    EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.
# ..    ...     ...                                                ...
# 91     92      95  TOYS, GAMES AND SPORTS REQUISITES; PARTS AND A...
# 92     93      96               MISCELLANEOUS MANUFACTURED ARTICLES.
# 93     94      97      WORKS OF ART COLLECTORS' PIECES AND ANTIQUES.
# 94     95      98                  PROJECT GOODS; SOME SPECIAL USES.
# 95     96      99                               MISCELLANEOUS GOODS.
#
#     2021-2022  2022-2023   %Growth
# 0    68083.83   81892.38     20.28
# 1       55.89      40.68    -27.22
# 2      589.29    1326.92    125.17
# 3     1578.39    1727.53      9.45
# 4    11635.70   15381.07     32.19
# ..        ...        ...       ...
# 91   10594.65    9640.57     -9.01
# 92    3730.18    3417.22     -8.39
# 93     191.42   34356.50  17848.70
# 94     248.10      94.22    -62.02
# 95      13.87       2.95    -78.75
#
# [96 rows x 6 columns]

# %%
df_filtered['%Growth'] = pd.to_numeric(df_filtered['%Growth'], errors='coerce')

# Step 1: Exclude rows with negative %Growth values
df_filtered = df_filtered[df_filtered['%Growth'] >= 0]

# Step 2: Calculate the mean of the '2022-2023' column
mean_2021_2022 = df_filtered['2021-2022'].mean()

# Step 3: Filter rows where '2022-2023' is greater than or equal to the mean
df_filtered = df_filtered[df_filtered['2021-2022'] >= mean_2021_2022]

# Step 4: Sort the remaining data by %Growth in descending order
df_sorted = df_filtered.sort_values(by='%Growth', ascending=False)

# Display the resulting dataframe
df_sorted.head()
# Out:
#     S.No.  HSCode                                          Commodity  \
# 24     25      27  MINERAL FUELS, MINERAL OILS AND PRODUCTS OF TH...
# 80     81      84  NUCLEAR REACTORS, BOILERS, MACHINERY AND MECHA...
# 68     69      71  NATURAL OR CULTURED PEARLS,PRECIOUS OR SEMIPRE...
# 86     87      90  OPTICAL, PHOTOGRAPHIC CINEMATOGRAPHIC MEASURIN...
# 59     60      62  ARTICLES OF APPAREL AND CLOTHING ACCESSORIES, ...
#
#     2021-2022   2022-2023  %Growth
# 24  611070.64  1023656.51    67.52
# 80  517877.13   787386.13    52.04
# 68  179257.35   267809.39    49.40
# 86  167182.62   232875.11    39.29
# 59  256306.06   314346.27    22.64
