# %%
# Load the CSV file to inspect its contents and pick out the top 5 countries based on growth percentage
import pandas as pd
file_path_csv = 'C:/Users/Sana/Downloads/SCMS_practical_class/Python/EDA/data/indonesia_commodities.csv'

# Read the CSV file
df_filtered = pd.read_csv(file_path_csv)

print(df_filtered)
# Out:
#     S.No.  HSCode                                          Commodity  \
# 0       1       2                        MEAT AND EDIBLE MEAT OFFAL.
# 1       2       3  FISH AND CRUSTACEANS, MOLLUSCS AND OTHER AQUAT...
# 2       3       4  DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDI...
# 3       4       5  PRODUCTS OF ANIMAL ORIGIN, NOT ELSEWHERE SPECI...
# 4       5       7    EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.
# ..    ...     ...                                                ...
# 89     90      95  TOYS, GAMES AND SPORTS REQUISITES; PARTS AND A...
# 90     91      96               MISCELLANEOUS MANUFACTURED ARTICLES.
# 91     92      97      WORKS OF ART COLLECTORS' PIECES AND ANTIQUES.
# 92     93      98                  PROJECT GOODS; SOME SPECIAL USES.
# 93     94      99                               MISCELLANEOUS GOODS.
#
#     2021-2022  2022-2023  %Growth
# 0   228833.03  252334.78    10.27
# 1     2390.31    7528.15   214.94
# 2    15068.13   14219.32    -5.63
# 3      510.42     170.28   -66.64
# 4    24463.84   42480.21    73.64
# ..        ...        ...      ...
# 89     292.37     398.38    36.26
# 90    8218.96   10777.83    31.13
# 91       3.80       3.11   -18.04
# 92      35.58     230.25   547.11
# 93       1.17       0.55   -52.97
#
# [94 rows x 6 columns]

# %%
df_filtered['%Growth'] = pd.to_numeric(df_filtered['%Growth'], errors='coerce')

# Step 1: Exclude rows with negative %Growth values
df_filtered = df_filtered[df_filtered['%Growth'] >= 0]

# Step 2: Calculate the mean of the '2022-2023' column
mean_2021_2022 = df_filtered['2021-2022'].mean()

# Step 3: Filter rows where '2022-2023' is greater than or equal to the mean
df_filtered = df_filtered[df_filtered['2021-2022'] >= mean_2021_2022]

# Step 4: Sort the remaining data by %Growth in descending order
df_sorted = df_filtered.sort_values(by='%Growth', ascending=False)

# Display the resulting dataframe
df_sorted.head()
# Out:
#     S.No.  HSCode                                          Commodity  \
# 7       8      10                                           CEREALS.
# 82     83      87  VEHICLES OTHER THAN RAILWAY OR TRAMWAY ROLLING...
# 24     25      27  MINERAL FUELS, MINERAL OILS AND PRODUCTS OF TH...
# 84     85      89              SHIPS, BOATS AND FLOATING STRUCTURES.
# 6       7       9                      COFFEE, TEA, MATE AND SPICES.
#
#      2021-2022   2022-2023  %Growth
# 7    128179.32   276563.90   115.76
# 82   324852.05   630376.52    94.05
# 24  1757681.14  3137440.44    78.50
# 84   191801.49   316045.11    64.78
# 6     64522.60    94698.69    46.77
